# %%
import csv
import pandas as pd
from sqlalchemy import create_engine

# %%
breed_file= "breed_labels.csv"
breed_df= pd.read_csv(breed_file)
breed_df.head()
# Out:
#    BreedID  Type         BreedName
# 0        1     1     Affenpinscher
# 1        2     1      Afghan Hound
# 2        3     1  Airedale Terrier
# 3        4     1            Akbash
# 4        5     1             Akita

# %%
engine = create_engine("sqlite:///pet_adoptions.sqlite", echo=False)

# %%
engine.table_names()
# Out:
# ['breed_labels', 'color_labels', 'train']

# %%
breed_df.to_sql(name='breed_labels', con=engine, if_exists='append', index=True)

# %%
color_file= "color_labels.csv"
color_df= pd.read_csv(color_file)
color_df.head()
# Out:
#    ColorID ColorName
# 0        1     Black
# 1        2     Brown
# 2        3    Golden
# 3        4    Yellow
# 4        5     Cream

# %%
color_df.to_sql(name='color_labels', con=engine, if_exists='append', index=True)

# %%
state_file= "train.csv"
state_df= pd.read_csv(state_file)
state_df.head()
# Out:
#    Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 0     2       Nibble    3     299       0       1       1       7       0
# 1     2  No Name Yet    1     265       0       1       1       2       0
# 2     1       Brisco    1     307       0       1       2       7       0
# 3     1         Miko    4     307       0       2       1       2       0
# 4     1       Hunter    1     307       0       1       1       0       0
#
#    MaturitySize      ...        Health  Quantity  Fee  State  \
# 0             1      ...             1         1  100  41326
# 1             2      ...             1         1    0  41401
# 2             2      ...             1         1    0  41326
# 3             2      ...             1         1  150  41401
# 4             2      ...             1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  8480853f516546f6cf33aa88cd76c379         0
# 1  3082c7125d8fb66f7dd4bff4192c8b14         0
# ...

# %%
state_df.to_sql(name='train', con=engine, if_exists='append', index=True)

# %%
color_id1=engine.execute("SELECT State from train where Color1 = 1")

for value in color_id1:
    print(value)
# Out:
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41361,)
# (41326,)
# (41327,)
# (41326,)
# (41336,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41327,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41335,)
# (41326,)
# (41327,)
# (41326,)
# (41325,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41327,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41327,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41332,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41335,)
# (41326,)
# (41332,)
# (41332,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41332,)
# (41326,)
# (41326,)
# (41401,)
# (41327,)
# (41330,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# ...

# %%
color_id2=engine.execute("SELECT State from train where Color1 = 2")

for value in color_id2:
    print(value)
# Out:
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41330,)
# (41326,)
# (41401,)
# (41327,)
# (41326,)
# (41326,)
# (41336,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41327,)
# (41326,)
# (41326,)
# (41324,)
# (41401,)
# (41336,)
# (41326,)
# (41326,)
# (41326,)
# (41330,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41336,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41332,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41327,)
# (41401,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41332,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41330,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41336,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41330,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41327,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# ...

# %%
color_id3=engine.execute("SELECT State from train where Color1 = 3")

for value in color_id3:
    print(value)
# Out:
# (41401,)
# (41326,)
# (41401,)
# (41401,)
# (41324,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41327,)
# (41327,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41401,)
# (41401,)
# (41401,)
# (41327,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41324,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41401,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41336,)
# (41327,)
# (41325,)
# (41330,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41324,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41325,)
# (41401,)
# (41327,)
# (41326,)
# (41326,)
# (41327,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41336,)
# (41401,)
# ...

# %%
color_id4=engine.execute("SELECT State from train where Color1 = 4")

for value in color_id4:
    print(value)
# Out:
# (41326,)
# (41401,)
# (41326,)
# (41324,)
# (41401,)
# (41401,)
# (41401,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41336,)
# (41326,)
# (41401,)
# (41401,)
# (41336,)
# (41401,)
# (41401,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41336,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41332,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41332,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41330,)
# (41401,)
# (41401,)
# (41401,)
# (41326,)
# (41401,)
# (41327,)
# (41336,)
# (41401,)
# (41324,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41345,)
# (41401,)
# (41326,)
# (41326,)
# (41336,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# ...

# %%
color_id5=engine.execute("SELECT State from train where Color1 = 5")

for value in color_id5:
    print(value)
# Out:
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41330,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41327,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41327,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41324,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41330,)
# (41326,)
# (41326,)
# (41327,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41401,)
# (41330,)
# (41330,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41330,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41324,)
# (41326,)
# (41327,)
# (41326,)
# (41326,)
# (41332,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41336,)
# (41326,)
# (41326,)
# (41401,)
# (41327,)
# (41326,)
# (41326,)
# ...

# %%
color_id6=engine.execute("SELECT State from train where Color1 = 6")

for value in color_id6:
    print(value)
# Out:
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41401,)
# (41401,)
# (41336,)
# (41326,)
# (41326,)
# (41336,)
# (41401,)
# (41326,)
# (41326,)
# (41336,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41330,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41336,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41327,)
# (41401,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41401,)
# (41401,)
# (41327,)
# (41326,)
# (41326,)
# (41401,)
# (41345,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# ...

# %%
color_id7=engine.execute("SELECT State from train where Color1 = 7")

for value in color_id7:
    print(value)
# Out:
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41401,)
# (41336,)
# (41330,)
# (41327,)
# (41401,)
# (41335,)
# (41326,)
# (41327,)
# (41326,)
# (41336,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41335,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41327,)
# (41326,)
# (41327,)
# (41326,)
# (41326,)
# (41330,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41332,)
# (41327,)
# (41326,)
# (41326,)
# (41327,)
# (41335,)
# (41324,)
# (41401,)
# (41327,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41401,)
# (41327,)
# (41336,)
# (41336,)
# (41326,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41326,)
# (41401,)
# (41401,)
# (41326,)
# (41401,)
# (41326,)
# (41326,)
# (41326,)
# (41327,)
# (41401,)
# (41335,)
# (41326,)
# (41401,)
# (41401,)
# (41336,)
# (41401,)
# (41327,)
# (41326,)
# ...

# %%
color_by_postcode= engine.execute("Select State, Color1, COUNT(COLOR1) from train Group By State, Color1")

for value in color_by_postcode:
    print(value)
# Out:
# (41324, 1, 159)
# (41324, 2, 135)
# (41324, 3, 27)
# (41324, 4, 15)
# (41324, 5, 24)
# (41324, 6, 15)
# (41324, 7, 36)
# (41325, 1, 189)
# (41325, 2, 66)
# (41325, 3, 36)
# (41325, 4, 3)
# (41325, 5, 21)
# (41325, 6, 6)
# (41325, 7, 9)
# (41326, 1, 13053)
# (41326, 2, 6723)
# (41326, 3, 1650)
# (41326, 4, 882)
# (41326, 5, 1575)
# (41326, 6, 1140)
# (41326, 7, 1119)
# (41327, 1, 1245)
# (41327, 2, 693)
# (41327, 3, 123)
# (41327, 4, 96)
# (41327, 5, 144)
# (41327, 6, 90)
# (41327, 7, 138)
# (41330, 1, 627)
# (41330, 2, 354)
# (41330, 3, 51)
# (41330, 4, 39)
# (41330, 5, 111)
# (41330, 6, 45)
# (41330, 7, 33)
# (41332, 1, 384)
# (41332, 2, 189)
# (41332, 3, 30)
# (41332, 4, 36)
# (41332, 5, 57)
# (41332, 6, 30)
# (41332, 7, 33)
# (41335, 1, 141)
# (41335, 2, 51)
# (41335, 3, 9)
# (41335, 4, 9)
# (41335, 5, 9)
# (41335, 6, 9)
# (41335, 7, 27)
# (41336, 1, 744)
# (41336, 2, 360)
# (41336, 3, 81)
# (41336, 4, 87)
# (41336, 5, 81)
# (41336, 6, 78)
# (41336, 7, 90)
# (41342, 1, 33)
# ...

# %%
breed_by_postcode= engine.execute("Select State, Breed1, COUNT(Breed1) from train GROUP BY State, Breed1 ")

for value in breed_by_postcode:
    print(value)
# Out:
# (41324, 98, 3)
# (41324, 109, 6)
# (41324, 141, 3)
# (41324, 152, 3)
# (41324, 179, 15)
# (41324, 190, 3)
# (41324, 195, 3)
# (41324, 205, 6)
# (41324, 218, 3)
# (41324, 265, 57)
# (41324, 266, 63)
# (41324, 285, 18)
# (41324, 292, 6)
# (41324, 296, 3)
# (41324, 299, 3)
# (41324, 307, 216)
# (41325, 39, 3)
# (41325, 103, 9)
# (41325, 109, 3)
# (41325, 141, 39)
# (41325, 152, 3)
# (41325, 179, 3)
# (41325, 195, 3)
# (41325, 205, 3)
# (41325, 218, 3)
# (41325, 251, 3)
# (41325, 254, 3)
# (41325, 264, 6)
# (41325, 265, 30)
# (41325, 266, 87)
# (41325, 268, 3)
# (41325, 285, 15)
# (41325, 289, 3)
# (41325, 292, 6)
# (41325, 297, 3)
# (41325, 307, 102)
# (41326, 0, 9)
# (41326, 1, 3)
# (41326, 3, 3)
# (41326, 5, 3)
# (41326, 10, 3)
# (41326, 15, 3)
# (41326, 17, 12)
# (41326, 18, 18)
# (41326, 19, 12)
# (41326, 20, 153)
# (41326, 24, 3)
# (41326, 25, 3)
# (41326, 26, 63)
# (41326, 31, 24)
# (41326, 32, 6)
# (41326, 39, 39)
# (41326, 42, 9)
# (41326, 44, 21)
# (41326, 49, 30)
# ...

# %%
adoptionspeed_by_postcode= engine.execute("Select State, AdoptionSpeed, COUNT(AdoptionSpeed) from train GROUP BY State, AdoptionSpeed ")

for value in adoptionspeed_by_postcode:
    print(value)
# Out:
# (41324, 0, 12)
# (41324, 1, 54)
# (41324, 2, 69)
# (41324, 3, 36)
# (41324, 4, 240)
# (41325, 0, 9)
# (41325, 1, 42)
# (41325, 2, 102)
# (41325, 3, 69)
# (41325, 4, 108)
# (41326, 0, 738)
# (41326, 1, 5631)
# (41326, 2, 7305)
# (41326, 3, 6012)
# (41326, 4, 6456)
# (41327, 0, 24)
# (41327, 1, 366)
# (41327, 2, 648)
# (41327, 3, 591)
# (41327, 4, 900)
# (41330, 0, 9)
# (41330, 1, 144)
# (41330, 2, 333)
# (41330, 3, 351)
# (41330, 4, 423)
# (41332, 0, 12)
# (41332, 1, 108)
# (41332, 2, 189)
# (41332, 3, 126)
# (41332, 4, 324)
# (41335, 0, 9)
# (41335, 1, 87)
# (41335, 2, 42)
# (41335, 3, 48)
# (41335, 4, 69)
# (41336, 0, 69)
# (41336, 1, 339)
# (41336, 2, 408)
# (41336, 3, 309)
# (41336, 4, 396)
# (41342, 0, 3)
# (41342, 1, 3)
# (41342, 3, 6)
# (41342, 4, 27)
# (41345, 0, 3)
# (41345, 1, 18)
# (41345, 2, 9)
# (41345, 3, 12)
# (41345, 4, 24)
# (41361, 1, 27)
# (41361, 2, 6)
# (41361, 3, 18)
# (41361, 4, 27)
# (41367, 0, 6)
# (41367, 1, 9)
# (41367, 2, 9)
# (41367, 3, 3)
# ...

# %%
geocoded_file= "geocoded_state_labels.csv"
geocoded_df= pd.read_csv(geocoded_file)
geocoded_df.head()
# Out:
#    StateID     StateName               LatLong
# 0    41336         Johor  1.934400, 103.358727
# 1    41325         Kedah  6.155672, 100.569649
# 2    41367      Kelantan  6.125397, 102.238068
# 3    41401  Kuala Lumpur     3.1412, 101.68653
# 4    41415        Labuan  5.285153, 115.247787

# %%
geocoded_df.to_sql(name='geocoded_file', con=engine, if_exists='append', index=True)

# %%
geocoded_file= engine.execute("Select StateID, LatLong from geocoded_file GROUP BY StateID ")

for value in geocoded_file:
    print(value)
# Out:
# (41324, '2.200844, 102.240143')
# (41325, '6.155672, 100.569649')
# (41326, '3.509247, 101.524803')
# (41327, '5.417071, 100.400011')
# (41330, '4.693950, 101.117577')
# (41332, '2.731813, 102.252502')
# (41335, '3.974341, 102.438057')
# (41336, '1.934400, 103.358727')
# (41342, '1.544765, 110.365219')
# (41345, '5.420404, 116.796783')
# (41361, '5.207053, 103.205299')
# (41367, '6.125397, 102.238068')
# (41380, '6.443589, 100.216599')
# (41401, '3.1412, 101.68653')
# (41415, '5.285153, 115.247787')

# %%
geocoded_file= engine.execute("Select StateName, LatLong from geocoded_file GROUP BY StateName ")

for value in geocoded_file:
    print(value)
# Out:
# ('Johor', '1.934400, 103.358727')
# ('Kedah', '6.155672, 100.569649')
# ('Kelantan', '6.125397, 102.238068')
# ('Kuala Lumpur', '3.1412, 101.68653')
# ('Labuan', '5.285153, 115.247787')
# ('Melaka', '2.200844, 102.240143')
# ('Negeri Sembilan', '2.731813, 102.252502')
# ('Pahang', '3.974341, 102.438057')
# ('Perak', '4.693950, 101.117577')
# ('Perlis', '6.443589, 100.216599')
# ('Pulau Pinang', '5.417071, 100.400011')
# ('Sabah', '5.420404, 116.796783')
# ('Sarawak', '1.544765, 110.365219')
# ('Selangor', '3.509247, 101.524803')
# ('Terengganu', '5.207053, 103.205299')
